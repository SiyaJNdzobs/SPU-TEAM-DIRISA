# %%
# 1.  Setup: Africa Check Water Factsheet
# Purpose:
# Set up the new extraction notebook, import required libraries,
# and define the raw-data output location.


from pathlib import Path
import requests
import pandas as pd
from bs4 import BeautifulSoup

# Project paths
PROJECT_ROOT = Path.cwd().parent
RAW_DIR = PROJECT_ROOT / "data" / "raw"

# here we Create raw-data directory
RAW_DIR.mkdir(parents=True, exist_ok=True)

# Source
WATER_URL = (
    "https://africacheck.org/fact-checks/"
    "factsheets/election-factsheet-water-south-africa"
)

# Output file
WATER_OUTPUT = RAW_DIR / "kzn_water_access_indicators.csv"

print("Setup completed successfully.")
print(f"Project root: {PROJECT_ROOT}")
print(f"Raw data directory: {RAW_DIR}")
print(f"Source: {WATER_URL}")
print(f"Output file: {WATER_OUTPUT}")
# Out:
# Setup completed successfully.
# Project root: C:\Users\Student\Downloads\Big Data\SPU-TEAM-DIRISA\notebooks
# Raw data directory: C:\Users\Student\Downloads\Big Data\SPU-TEAM-DIRISA\notebooks\data\raw
# Source: https://africacheck.org/fact-checks/factsheets/election-factsheet-water-south-africa
# Output file: C:\Users\Student\Downloads\Big Data\SPU-TEAM-DIRISA\notebooks\data\raw\kzn_water_access_indicators.csv
